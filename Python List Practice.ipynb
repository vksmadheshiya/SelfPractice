# %%
x = lambda x : [i for i in x ]

# %%
x([3,4,5,6])
# Out:
# [3, 4, 5, 6]

# %%
l1 = [3, 4, 5, 6]
for i in l1:
  print(i)
  # l1.append(i)
# Out:
# 3
# 4
# 5
# 6

# %%
a = lambda **kwargs : kwargs

# %%
a(a=45,b=56)
# Out:
# {'a': 45, 'b': 56}

# %%
a=100
def test16(c, d ):
  return c*d

# %%
test16(a,50)
# Out:
# 5000

# %%
c=10

# %%
l = [1,2,3,4,5,6,7,8,9,0]
l1=[]
for i in l:
  l1.append(i+2)

# %%
l1
# Out:
# [3, 4, 5, 6, 7, 8, 9, 10, 11, 2]

# %%
def test17(a):
  l1=[]
  for i in a :
    l1.append(i+2)
  return

# %%
print(test17(l))
# Out:
# None

# %%
a = lambda a : [i+2 for i in a ]

# %%
a(l)
# Out:
# [3, 4, 5, 6, 7, 8, 9, 10, 11, 2]

# %%
[(i**2, i+1 ) for i in l if i<4]
# Out:
# [(1, 2), (4, 3), (9, 4), (0, 1)]

# %%
l1 = []
for i in l :
  if i < 4:
    l1.append((i**2, i+1))

# %%
l1
# Out:
# [(1, 2), (4, 3), (9, 4), (0, 1)]

# %%
d = {1:1, 2:4, 3:9}

# %%
{i:i**2 for i in range(10)}
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
(i for i in range(10))
# Out:
# <generator object <genexpr> at 0x7f8ca8accf50>
